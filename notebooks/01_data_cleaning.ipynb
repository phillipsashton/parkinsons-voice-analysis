# %%
import pandas as pd
import numpy as np
import os

# %%
raw_path = "../data/raw/parkinsons.data"

df = pd.read_csv(raw_path)

df["patient_id"] = df["name"].str.extract(r"(S\d+)")

df.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#        NHR     HNR  status      RPDE       DFA   spread1   spread2        D2  \
# ...

# %%
df.shape
# Out:
# (195, 25)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    str
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
df.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# patient_id          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Checking the class distribution helps determine whether the dataset is balanced or imbalanced.

# %%
df["status"].value_counts()
# Out:
# status
# 1    147
# 0     48
# Name: count, dtype: int64

# %%
df["status"].value_counts(normalize=True)
# Out:
# status
# 1    0.753846
# 0    0.246154
# Name: proportion, dtype: float64

# %% [markdown]
# The dataset contains multiple voice recordings from the same individuals. Because of this, I need to extract a patient identifier from the `name` column. This will be important later because recordings from the same patient should not be split across both training and testing data.

# %%
df[["name", "patient_id", "status"]].head(10)
# Out:
#              name patient_id  status
# 0  phon_R01_S01_1        S01       1
# 1  phon_R01_S01_2        S01       1
# 2  phon_R01_S01_3        S01       1
# 3  phon_R01_S01_4        S01       1
# 4  phon_R01_S01_5        S01       1
# 5  phon_R01_S01_6        S01       1
# 6  phon_R01_S02_1        S02       1
# 7  phon_R01_S02_2        S02       1
# 8  phon_R01_S02_3        S02       1
# 9  phon_R01_S02_4        S02       1

# %%
df["patient_id"].nunique()
# Out:
# 32

# %%
recordings_per_patient = df.groupby("patient_id")["name"].count()

recordings_per_patient.describe()
# Out:
# count    32.000000
# mean      6.093750
# std       0.296145
# min       6.000000
# 25%       6.000000
# 50%       6.000000
# 75%       6.000000
# max       7.000000
# Name: name, dtype: float64

# %%
recordings_per_patient.sort_index()
# Out:
# patient_id
# S01    6
# S02    6
# S04    6
# S05    6
# S06    6
# S07    6
# S08    6
# S10    6
# S13    6
# S16    6
# S17    6
# S18    6
# S19    6
# S20    6
# S21    7
# S22    6
# S24    6
# S25    6
# S26    6
# S27    7
# S31    6
# S32    6
# S33    6
# S34    6
# S35    7
# S37    6
# S39    6
# S42    6
# S43    6
# S44    6
# S49    6
# S50    6
# Name: name, dtype: int64

# %% [markdown]
# Each patient should belong to only one diagnosis class. This check confirms whether any extracted patient ID appears with both healthy and Parkinson’s labels.

# %%
patient_status_counts = df.groupby("patient_id")["status"].nunique()

patient_status_counts.value_counts()
# Out:
# status
# 1    32
# Name: count, dtype: int64

# %%
df.groupby("patient_id")["status"].first().value_counts()
# Out:
# status
# 1    24
# 0     8
# Name: count, dtype: int64

# %% [markdown]
# The extracted patient IDs show the patient-level class distribution. This is separate from the recording-level class distribution because each patient has multiple recordings.
#
#
# The dataset features are grouped by the type of voice measurement they represent. These groups will make the EDA easier to organize.

# %%
frequency_features = [
    "MDVP:Fo(Hz)",
    "MDVP:Fhi(Hz)",
    "MDVP:Flo(Hz)"
]

jitter_features = [
    "MDVP:Jitter(%)",
    "MDVP:Jitter(Abs)",
    "MDVP:RAP",
    "MDVP:PPQ",
    "Jitter:DDP"
]

shimmer_features = [
    "MDVP:Shimmer",
    "MDVP:Shimmer(dB)",
    "Shimmer:APQ3",
    "Shimmer:APQ5",
    "MDVP:APQ",
    "Shimmer:DDA"
]

noise_features = [
    "NHR",
    "HNR"
]

nonlinear_features = [
    "RPDE",
    "DFA",
    "spread1",
    "spread2",
    "D2",
    "PPE"
]

all_feature_columns = (
    frequency_features +
    jitter_features +
    shimmer_features +
    noise_features +
    nonlinear_features
)

# %% [markdown]
# All voice biomarker columns should be numeric. This check confirms that the feature columns are stored as numeric data types.

# %%
df[all_feature_columns].dtypes
# Out:
# MDVP:Fo(Hz)         float64
# MDVP:Fhi(Hz)        float64
# MDVP:Flo(Hz)        float64
# MDVP:Jitter(%)      float64
# MDVP:Jitter(Abs)    float64
# MDVP:RAP            float64
# MDVP:PPQ            float64
# Jitter:DDP          float64
# MDVP:Shimmer        float64
# MDVP:Shimmer(dB)    float64
# Shimmer:APQ3        float64
# Shimmer:APQ5        float64
# MDVP:APQ            float64
# Shimmer:DDA         float64
# NHR                 float64
# HNR                 float64
# RPDE                float64
# DFA                 float64
# spread1             float64
# spread2             float64
# D2                  float64
# PPE                 float64
# dtype: object

# %% [markdown]
# Before saving the cleaned dataset, I will confirm the dataset shape, missing values, duplicate count, and final column list.

# %%
print("shape: ", df.shape)
print("null sum: ", df.isnull().sum())
print("columns: ", df.columns)
print("duplicated sum: ", df.duplicated().sum())
# Out:
# shape:  (195, 25)
# null sum:  name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# patient_id          0
# dtype: int64
# columns:  Index(['name', 'MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'status', 'RPDE', 'DFA',
# ...

# %%
processed_dir = "../data/processed"
os.makedirs(processed_dir, exist_ok=True)

cleaned_path = os.path.join(processed_dir, "parkinsons_cleaned.csv")

df.to_csv(cleaned_path, index=False)

cleaned_path
# Out:
# '../data/processed/parkinsons_cleaned.csv'

# %%
cleaned_df = pd.read_csv(cleaned_path)

cleaned_df.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#        NHR     HNR  status      RPDE       DFA   spread1   spread2        D2  \
# ...
